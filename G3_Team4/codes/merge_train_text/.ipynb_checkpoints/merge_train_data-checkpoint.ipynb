# %% [markdown]
# # Merge LDA , k means , textblov and vader for train set

# %%
## Import packages

import numpy as np
import pandas as pd
import copy

# %%
kmeans = pd.read_csv('kmeans_train_text.csv')
kmeans.head(5)
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  K_means
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1        2
# 1  Ever get the feeling your life circles the rou...      0        1
# 2  Why the Truth Might Get You Fired October 29, ...      1        2
# 3  Videos 15 Civilians Killed In Single US Airstr...      1        2
# 4  Print \nAn Iranian woman has been sentenced to...      1        2

# %%
lda = pd.read_csv('lda_train_text_5.csv')
lda.head(5)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             2.0              0.7499
# 1            1             2.0              0.6950
# 2            2             0.0              0.5489
# 3            3             0.0              0.9062
# 4            4             0.0              0.4749
#
#                                             Keywords  \
# 0      i s t it the clinton trump people you hillary
# 1      i s t it the clinton trump people you hillary
# 2  s mr trump the said president state obama gove...
# 3  s mr trump the said president state obama gove...
# 4  s mr trump the said president state obama gove...
#
#                                                 Text
# 0  ['house', 'dem', 'aide', 'we', 'didn', 't', 'e...
# 1  ['ever', 'feeling', 'life', 'circles', 'rounda...
# 2  ['why', 'truth', 'might', 'get', 'you', 'fired...
# 3  ['videos', 'civilians', 'killed', 'in', 'singl...
# 4  ['print', 'an', 'iranian', 'woman', 'sentenced...

# %%
trainVader = pd.read_csv('old/vaderkmeansdata.csv', encoding='latin-1')
trainVader.head(5)
# Out:
#    id              author  label  \
# 0   0       Darrell Lucus      1
# 1   1     Daniel J. Flynn      0
# 2   2  Consortiumnews.com      1
# 3   3     Jessica Purkiss      1
# 4   4      Howard Portnoy      1
#
#                                                 text  \
# 0  house dem aide didnt even see comeys letter ja...
# 1  ever get feeling life circle roundabout rather...
# 2  truth might get fired october tension intellig...
# 3  video civilian killed single u airstrike ident...
# 4  print iranian woman sentenced six year prison ...
#
#                                                title  compound  K_means
# 0  house dem aide didnt even see comeys letter ja...    0.5431        0
# 1   flynn hillary clinton big woman campus breitbart   -0.4405        2
# 2                              truth might get fired    0.9853        0
# 3      civilian killed single u airstrike identified   -0.9993        0
# 4  iranian woman jailed fictional unpublished sto...   -0.9517        0

# %%
trainTextblob = pd.read_csv('textblobText.csv' , encoding='latin-1')
trainTextblob.head(5)
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didnât Even See Comeyâs...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didnât Even See Comeyâs...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                           text_clean    tb_Pol   tb_Subj
# ...

# %%
print(kmeans.shape)
print(lda.shape)
print(trainVader.shape)
print(trainTextblob.shape)
# Out:
# (20800, 6)
# (20800, 5)
# (20800, 7)
# (20800, 8)

# %%
def Sentiscore(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Postive'

# %%
merged_train_data = pd.DataFrame(kmeans,columns=['id', 'title' , 'text' , 'K_means'])
merged_train_data['LDA_Dominant_Topic'] = lda['Dominant_Topic']
merged_train_data['text_vader_compound'] = trainVader['compound']
merged_train_data['text_vader_neg'] = trainVader['neg']
merged_train_data['text_vader_neu'] = trainVader['neu']
merged_train_data['text_vader_pos'] = trainVader['pos']
merged_train_data['tb_Pol'] = trainTextblob['tb_Pol']
merged_train_data['tb_Subj'] = trainTextblob['tb_Subj']
merged_test_data['Polarity_category'] = trainTextblob['tb_Pol'].apply(Sentiscore)
merged_train_data.head(4)

# %%
# print(merged_train_data.shape)
# merged_train_data.isna().sum()

# %%
# merged_train_data.dtypes

# %%
# merged_test_data.to_csv('merged_train_data.csv', index=False)
# dt_csv = pd.read_csv('merged_train_data.csv')
